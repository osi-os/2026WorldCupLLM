# %%
print('hi')
# Out:
# hi

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
from rag import get_rag

rag = get_rag(llm_client=Anthropic())

print(rag.rag("Who was the player of the match in the Mexico South Africa game?"))
# Out:
# Based on the context provided, **Julián Andrés Quinones** was the player of the match in the Mexico vs South Africa game on June 11, 2026.
#
# Mexico won 2-0, and Quinones scored the opening goal in the 9th minute with an assist from Erik Antonio Lira.
